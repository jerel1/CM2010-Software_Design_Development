# %%
import unittest
import snakestats
class TestsForSnakeStats(unittest.TestCase):
    
    def test_mean_3_values(self):
        res = snakestats.mean([1,2,3])
        self.assertEqual(res, 2.0)
        
    def test_mean_2_values(self):
        res = snakestats.mean([1,2])
        self.assertEqual(res, 1.5)
        
    def test_getMax(self):
        theMax = snakestats.getMax([6,5,4,3,2,1])
        self.assertEqual(theMax, 6)

    def test_getMax_Negative(self):
        theMax = snakestats.getMax([-6,-5,-4,-3,-2,-1])
        self.assertEqual(theMax, -1)
        
unittest.main(argv=['ignored','-v'], exit=False)
# Out:
# test_getMax (__main__.TestsForSnakeStats.test_getMax) ... ok
# test_getMax_Negative (__main__.TestsForSnakeStats.test_getMax_Negative) ... ok
# test_mean_2_values (__main__.TestsForSnakeStats.test_mean_2_values) ... ok
# test_mean_3_values (__main__.TestsForSnakeStats.test_mean_3_values) ... ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.001s
#
# OK

# %%
class TestSetForOneModule(unittest.TestCase):
    def test_arithmetic_pass(self):
        ans = 2 + 2
        self.assertNotEqual(ans,2)
    def test_arithmetic_fail(self):
        self.assertEqual(2,3)

unittest.main(argv=['ignored','-v'], exit=False)
# Out:
# test_arithmetic_fail (__main__.TestSetForOneModule.test_arithmetic_fail) ... FAIL
# test_arithmetic_pass (__main__.TestSetForOneModule.test_arithmetic_pass) ... ok
# test_getMax (__main__.TestsForSnakeStats.test_getMax) ... ok
# test_getMax_Negative (__main__.TestsForSnakeStats.test_getMax_Negative) ... ok
# test_mean_2_values (__main__.TestsForSnakeStats.test_mean_2_values) ... ok
# test_mean_3_values (__main__.TestsForSnakeStats.test_mean_3_values) ... ok
#
# ======================================================================
# FAIL: test_arithmetic_fail (__main__.TestSetForOneModule.test_arithmetic_fail)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/var/folders/5z/p3ztq1pj6xs44cv1pyb2yccw0000gn/T/ipykernel_70965/2848988046.py", line 6, in test_arithmetic_fail
#     self.assertEqual(2,3)
# AssertionError: 2 != 3
#
# ----------------------------------------------------------------------
# Ran 6 tests in 0.005s
#
# FAILED (failures=1)
